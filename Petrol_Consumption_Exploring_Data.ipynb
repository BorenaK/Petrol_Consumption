# %% [markdown]
# ## Petrol Consumption

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('petrol_consumption.csv')

# %% [markdown]
# ### Explore Data

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
df.tail()
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 43         7.0            3745            2611                         0.508
# 44         6.0            5215            2302                         0.672
# 45         9.0            4476            3942                         0.571
# 46         7.0            4296            4083                         0.623
# 47         7.0            5002            9794                         0.593
#
#     Petrol_Consumption
# 43                 591
# 44                 782
# 45                 510
# 46                 610
# 47                 524

# %%
df.columns
# Out:
# Index(['Petrol_tax', 'Average_income', 'Paved_Highways',
#        'Population_Driver_licence(%)', 'Petrol_Consumption'],
#       dtype='object')

# %%
df.shape
# Out:
# (48, 5)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
df.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
df['Petrol_tax'].value_counts(dropna=False)
# Out:
# 7.00     19
# 8.00     10
# 9.00      8
# 7.50      4
# 8.50      3
# 6.58      1
# 6.00      1
# 5.00      1
# 10.00     1
# Name: Petrol_tax, dtype: int64

# %%
df['Petrol_tax'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Population_Driver_licence(%)'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Petrol_tax'}>,
#         <AxesSubplot:title={'center':'Average_income'}>],
#        [<AxesSubplot:title={'center':'Paved_Highways'}>,
#         <AxesSubplot:title={'center':'Population_Driver_licence(%)'}>],
#        [<AxesSubplot:title={'center':'Petrol_Consumption'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
# check number of null values by columns
df.isnull().sum()
# Out:
# Petrol_tax                      0
# Average_income                  0
# Paved_Highways                  0
# Population_Driver_licence(%)    0
# Petrol_Consumption              0
# dtype: int64

# %%
sns.barplot(data=df, x='Petrol_Consumption', y='Average_income',)
plt.ylim(3000,6000)
plt.show()

# %%
sns.pointplot(x='Petrol_Consumption', y='Average_income', hue='Petrol_tax', data=df)
# Out:
# <AxesSubplot:xlabel='Petrol_Consumption', ylabel='Average_income'>

# %% [markdown]
# ### Exploring distribution

# %%
sns.violinplot(data=df, x="Petrol_Consumption", y="Average_income")
plt.show()

# %%
plot = sns.displot(df.Petrol_Consumption, kde=False, color="b")

# %%
plot = sns.displot(df.Average_income, kde=False, color="b")

# %% [markdown]
# ### Regression Plot

# %%
 sns.regplot(x="Average_income", y="Petrol_Consumption", data=df)
# Out:
# <AxesSubplot:xlabel='Average_income', ylabel='Petrol_Consumption'>

# %%
 sns.regplot(x="Paved_Highways", y="Petrol_Consumption", data=df)
# Out:
# <AxesSubplot:xlabel='Paved_Highways', ylabel='Petrol_Consumption'>

# %%
 sns.regplot(x="Average_income", y="Population_Driver_licence(%)", data=df)
# Out:
# <AxesSubplot:xlabel='Average_income', ylabel='Population_Driver_licence(%)'>
